# %% [markdown]
# # Loading the ROS node model

# %% [markdown]
# First we need to load the ROS node model in Imandra. We do that using `System.mod_use` to first load the necessary messaging modules:

# %%
System.mod_use ~quiet:true "src-messages/basic_types.ml";;
System.mod_use ~quiet:true "src-messages/std_msgs.ml";;
System.mod_use ~quiet:true "src-messages/rosgraph_msgs.ml";;
System.mod_use ~quiet:true "src-messages/geometry_msgs.ml";;
System.mod_use ~quiet:true "src-messages/sensor_msgs.ml";;
System.mod_use ~quiet:true "src-model/ros_complex_model.ml";;
open Ros_complex_model;;
# Out:
# - : unit = ()
# - : unit = ()
# - : unit = ()
# - : unit = ()
# - : unit = ()
# - : unit = ()

# %% [markdown]
# The model has a `state` datatype and a `one_step : state -> state` transition function.

# %%
#show state;;
# Out:
# type nonrec state = {
#   mode : Ros_complex_model.mode;
#   incoming : Ros_complex_model.incoming option;
#   outgoing : Ros_complex_model.outgoing option;
# }

# %% [markdown]
# The `state` contains two "slots" for incoming and outgoing messages and a `mode` value that describes the current  behaviour mode of our robot:

# %%
#show mode;;
# Out:
# type nonrec mode = Stopped | Turning | Driving | Error

# %% [markdown]
# Our robot starts in the `Stopped`  mode and then transitions between `Turning` and `Driving` modes, reacting to the sensor inputs.

# %%
one_step;;
# Out:
# - : Ros_complex_model.state -> Ros_complex_model.state = <fun>

# %% [markdown]
# # Verifying error mode transition

# %% [markdown]
# First thing that we want to verify it that our node will not go into an `Error` mode unless it receives an invalid message.  We can formalize this statement as the following logical expression:
#
# $$ \forall s. ( Mode(s) \ne Error) \,\land\, Valid(IncomingMessage(s)) \,\Rightarrow\, (Mode(one\_step(s)) \ne Error) $$
#
# Meaning that for every state $s$, if the state is not already in the `Error` mode and its incoming message is valid, then the state's mode after we've called `one_step` on it is never the `Error` mode.
#
# We can almost literally encode this formal excpresson as an Imandra `theorem`:

# %%
theorem error_state_invalid_message state =
  match state.incoming with None -> true | Some msg -> 
  (  state.mode <> Error 
  && valid_incoming msg  
  ) ==> (one_step state).mode <> Error
# Out:
# val error_state_invalid_message : Ros_complex_model.state -> bool = <fun>
# <div><div>Proved<div class="imandra-alternatives" id="alt-aa0c7cd9-0820-4988-ac32-1fd2bdad1881"><ul class="nav nav-tabs"><li class="active" data-toggle="tab"><a>proof</a></li><li class="" data-toggle="tab"><a>call graph</a></li></ul><div class="tab-content"><div class="tab-pane active"><div class="imandra-proof-top"><div class="imandra-fold panel panel-default" id="fold-03b42fa3-b66c-419a-8125-99327955d4e6"><div class="panel-heading"><div><i class="fa fa-chevron-down hidden"></i><i class="fa fa-chevron-right"></i><span>proof</span></div></div><div class="panel-body collapse"><div class="imandra-proof"><div class="imandra-alternatives" id="alt-6df90c24-2313-4a82-b493-8ce93a5fd6f0"><ul class="nav nav-tabs"><li class="active" data-toggle="tab"><a>summary</a></li><li class="" data-toggle="tab"><a>full</a></li><li class="" data-toggle="tab"><a>graph</a></li></ul><div class="tab-content"><div class="tab-pane active"><div class="imandra-table" id="table-4af581f9-e1c6-48f1-a51b-8d09962d7b6d"><table><tr><td><b>ground_instances</b></td><td>0</td></tr><tr><td><b>definitions</b></td><td>0</td></tr><tr><td><b>inductions</b></td><td>0</td></tr><tr><td><b>search_time</b></td><td><pre>0.007s</pre></td></tr><tr><td><b>details</b></td><td><div class="imandra-fold panel panel-default" id="fold-81eeaff4-d76f-4dfd-b541-ecfc919a549d"><div class="panel-heading"><div><i class="fa fa-chevron-down hidden"></i><i class="fa fa-chevron-right"></i><span>Expand</span></div></div><div class="panel-body collapse"><div class="imandra-table" id="table-2653d1d5-fe29-4ae4-aaaa-6570c0ab6916"><table><tr><td><b>smt_stats</b></td><td>(:added-eqs               209
#  :conflicts               19
#  :datatype-accessor-ax    47
#  :datatype-constructor-ax 31
#  :datatype-splits         8
#  :decisions               38
#  :del-clause              12
#  :max-memory              16.21
#  :memory                  10.42
#  :minimized-lits          3
#  :mk-bool-var             163
#  :mk-clause               48
#  :num-allocs              527480132
#  :num-checks              2
#  :propagations            98
#  :rlimit-count            67557
#  :seq-num-reductions      1)</td></tr></table></div></div><script>
# require(['nbextensions/nbimandra/fold'], function (fold) {
#   var target = '#fold-81eeaff4-d76f-4dfd-b541-ecfc919a549d';
#   fold.hydrate(target);
# });
# </script></div></td></tr></table></div></div><div class="tab-pane"><div class="imandra-fold panel panel-default" id="fold-443a7eb1-45e6-494a-828c-1cbae9fa9ed4"><div class="panel-heading"><div><i class="fa fa-chevron-down hidden"></i><i class="fa fa-chevron-right"></i><span>Expand</span></div></div><div class="panel-body collapse"><ul><li><pre>start[0.007s]
#   if :var_0:.Ros_complex_model.incoming = None then true
#   else
#     not (:var_0:.Ros_complex_model.mode = Ros_complex_model.Error)
#     &amp;&amp; (if Is_a(Ros_complex_model.Sensor,
#            Option.get :var_0:.Ros_complex_model.incoming)
#         then List.length ….Sensor_msgs.laserScan_ranges = 5 else true)
#     ==&gt; not
#         ((if :var_0:.Ros_complex_model.mode = Ros_complex_model.Error
#           then
#             {Ros_complex_model.mode = :var_0:.Ros_complex_model.mode;
#              Ros_complex_model.incoming = :var_0:.Ros_complex_model.incoming;
#              Ros_complex_model.outgoing = …}
#           else
#           if :var_0:.Ros_complex_model.incoming = None
#           then
#             {Ros_complex_model.mode = :var_0:.Ros_complex_model.mode;
#              Ros_complex_model.incoming = :var_0:.Ros_complex_model.incoming;
#              Ros_complex_model.outgoing = …}
#           else …).Ros_complex_model.mode
#          = Ros_complex_model.Error)</pre></li><li><div><h4>simplify</h4><div class="imandra-table" id="table-66e58db5-fc75-4e0e-b8d4-3d5b169ff7ce"><table><tr><td><b>into</b></td><td><pre>(:var_0:.Ros_complex_model.incoming = None
#  || not
#     (not (:var_0:.Ros_complex_model.mode = Ros_complex_model.Error)
#      &amp;&amp; (not
#          Is_a(Ros_complex_model.Sensor,
#          Option.get :var_0:.Ros_complex_model.incoming)
#          || List.length
#             (Destruct(Ros_complex_model.Sensor, 0,
#                       Option.get :var_0:.Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges
#             = 5)))
# || not
#    ((if :var_0:.Ros_complex_model.mode = Ros_complex_model.Error
#      then
#        {Ros_complex_model.mode = :var_0:.Ros_complex_model.mode;
#         Ros_complex_model.incoming = :var_0:.Ros_complex_model.incoming;
#         Ros_complex_model.outgoing = None}
#      else
#      if :var_0:.Ros_complex_model.incoming = None
#      then
#        {Ros_complex_model.mode = :var_0:.Ros_complex_model.mode;
#         Ros_complex_model.incoming = :var_0:.Ros_complex_model.incoming;
#         Ros_complex_model.outgoing = None}
#      else
#      if not
#         Is_a(Ros_complex_model.Sensor,
#         Option.get :var_0:.Ros_complex_model.incoming)
#         || List.length
#            (Destruct(Ros_complex_model.Sensor, 0,
#                      Option.get :var_0:.Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges
#            = 5
#      then … else …).Ros_complex_model.mode
#     = Ros_complex_model.Error)</pre></td></tr><tr><td><b>expansions</b></td><td><pre>[]</pre></td></tr><tr><td><b>rewrite_steps</b></td><td><ul></ul></td></tr><tr><td><b>forward_chaining</b></td><td><ul></ul></td></tr></table></div></div></li><li><div><h4>unsat</h4><pre>(let ((a!1 (= (Ros_complex_model.mode_2589
#                 (rec_mk.Ros_complex_model.state_2638
#     …</pre></div></li></ul></div><script>
# require(['nbextensions/nbimandra/fold'], function (fold) {
#   var target = '#fold-443a7eb1-45e6-494a-828c-1cbae9fa9ed4';
#   fold.hydrate(target);
# });
# </script></div></div><div class="tab-pane"><div class="imandra-graphviz" id="graphviz-cbd58517-44bc-4898-8010-8aad5cb4df9c"><textarea style="display: none">digraph &quot;proof&quot; {
# p_199 [label=&quot;Start (if :var_0:.Ros_complex_model.incoming = None then true\l       else\l         not (:var_0:.Ros_complex_model.mode = Ros_complex_model.Error)\l         &amp;&amp; (if Is_a(Ros_complex_model.Sensor,\l                Option.get :var_0:.Ros_complex_model.incoming)\l             then List.length ….Sensor_msgs.laserScan_ranges = 5 else true)\l         ==\&gt; not\l             ((if :var_0:.Ros_complex_model.mode = Ros_complex_model.Error\l               then\l                 \{Ros_complex_model.mode = :var_0:.Ros_complex_model.mode;\l                  Ros_complex_model.incoming =\l                  :var_0:.Ros_complex_model.incoming;\l                  Ros_complex_model.outgoing = …\}\l               else\l               if :var_0:.Ros_complex_model.incoming = None\l               then\l                 \{Ros_complex_model.mode = :var_0:.Ros_complex_model.mode;\l                  Ros_complex_model.incoming =\l                  :var_0:.Ros_complex_model.incoming;\l                  Ros_complex_model.outgoing = …\}\l               else …).Ros_complex_model.mode\l              = Ros_complex_model.Error)\l       :time 0.007s)&quot;,shape=box,style=filled,fontname=&quot;courier&quot;,fontsize=14];
# p_199 -&gt; p_198 [label=&quot;&quot;];
# p_198 [label=&quot;Simplify ((:var_0:.Ros_complex_model.incoming = None\l           \|\| not\l              (not (:var_0:.Ros_complex_model.mode = Ros_complex_model.Error)\l               &amp;&amp; (not\l                   Is_a(Ros_complex_model.Sensor,\l                   Option.get :var_0:.Ros_complex_model.incoming)\l                   \|\| List.length\l                      (Destruct(Ros_complex_model.Sensor, 0,\l                                Option.get :var_0:.Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges\l                      = 5)))\l          \|\| not\l             ((if :var_0:.Ros_complex_model.mode = Ros_complex_model.Error\l               then\l                 \{Ros_complex_model.mode = :var_0:.Ros_complex_model.mode;\l                  Ros_complex_model.incoming =\l                  :var_0:.Ros_complex_model.incoming;\l                  Ros_complex_model.outgoing = None\}\l

# %% [markdown]
# One can see that the theorem is "Proven", meaning that Imandra has formally checked that this property holds for all possible input states.
#
# Let's also verify that in the `Error` mode our model ingnores all the incoming messages:

# %%
theorem error_state_ignores_messages state =
  match state.incoming with None -> true | Some msg -> 
  (  state.mode = Error 
  && state.outgoing = None
  ) ==> state.outgoing = None
# Out:
# val error_state_ignores_messages : Ros_complex_model.state -> bool = <fun>
# <div><div>Proved<div class="imandra-alternatives" id="alt-6379ea32-2dfb-408e-9874-538e3c13208f"><ul class="nav nav-tabs"><li class="active" data-toggle="tab"><a>proof</a></li><li class="" data-toggle="tab"><a>call graph</a></li></ul><div class="tab-content"><div class="tab-pane active"><div class="imandra-proof-top"><div class="imandra-fold panel panel-default" id="fold-7866e987-5288-4450-b071-99a01ae4d36f"><div class="panel-heading"><div><i class="fa fa-chevron-down hidden"></i><i class="fa fa-chevron-right"></i><span>proof</span></div></div><div class="panel-body collapse"><div class="imandra-proof"><div class="imandra-alternatives" id="alt-4d2d882b-3cc2-4698-b452-31384fa9eb78"><ul class="nav nav-tabs"><li class="active" data-toggle="tab"><a>summary</a></li><li class="" data-toggle="tab"><a>full</a></li><li class="" data-toggle="tab"><a>graph</a></li></ul><div class="tab-content"><div class="tab-pane active"><div class="imandra-table" id="table-a622f951-248f-4661-ad4f-0edff7f1d6b4"><table><tr><td><b>ground_instances</b></td><td>0</td></tr><tr><td><b>definitions</b></td><td>0</td></tr><tr><td><b>inductions</b></td><td>0</td></tr><tr><td><b>search_time</b></td><td><pre>0.009s</pre></td></tr><tr><td><b>details</b></td><td><div class="imandra-fold panel panel-default" id="fold-748eccb7-cc88-45a1-8eac-84f37ec315ea"><div class="panel-heading"><div><i class="fa fa-chevron-down hidden"></i><i class="fa fa-chevron-right"></i><span>Expand</span></div></div><div class="panel-body collapse"><div class="imandra-table" id="table-90f694af-e041-4345-a941-82e7c0075893"><table><tr><td><b>smt_stats</b></td><td>(:max-memory   16.21
#  :memory       13.28
#  :mk-bool-var  5
#  :num-allocs   560187240
#  :rlimit-count 67611)</td></tr></table></div></div><script>
# require(['nbextensions/nbimandra/fold'], function (fold) {
#   var target = '#fold-748eccb7-cc88-45a1-8eac-84f37ec315ea';
#   fold.hydrate(target);
# });
# </script></div></td></tr></table></div></div><div class="tab-pane"><div class="imandra-fold panel panel-default" id="fold-095eb3ec-ee43-4233-9e3d-21ed0d72556e"><div class="panel-heading"><div><i class="fa fa-chevron-down hidden"></i><i class="fa fa-chevron-right"></i><span>Expand</span></div></div><div class="panel-body collapse"><ul><li><pre>start[0.009s]
#   if :var_0:.Ros_complex_model.incoming = None then true
#   else
#     :var_0:.Ros_complex_model.mode = Ros_complex_model.Error
#     &amp;&amp; :var_0:.Ros_complex_model.outgoing = None
#     ==&gt; :var_0:.Ros_complex_model.outgoing = None</pre></li><li><div><h4>simplify</h4><div class="imandra-table" id="table-20edae64-38d6-4fae-8a56-a7063617d2d4"><table><tr><td><b>into</b></td><td><pre>(:var_0:.Ros_complex_model.incoming = None
#  || not
#     (:var_0:.Ros_complex_model.mode = Ros_complex_model.Error
#      &amp;&amp; :var_0:.Ros_complex_model.outgoing = None))
# || :var_0:.Ros_complex_model.outgoing = None</pre></td></tr><tr><td><b>expansions</b></td><td><pre>[]</pre></td></tr><tr><td><b>rewrite_steps</b></td><td><ul></ul></td></tr><tr><td><b>forward_chaining</b></td><td><ul></ul></td></tr></table></div></div></li><li><div><h4>unsat</h4><pre>(let ((a!1 (asserted (not (= (Ros_complex_model.outgoing_2591 state_2691)
#                           …</pre></div></li></ul></div><script>
# require(['nbextensions/nbimandra/fold'], function (fold) {
#   var target = '#fold-095eb3ec-ee43-4233-9e3d-21ed0d72556e';
#   fold.hydrate(target);
# });
# </script></div></div><div class="tab-pane"><div class="imandra-graphviz" id="graphviz-121b1787-02e4-4ed6-9474-9770be2cdd17"><textarea style="display: none">digraph &quot;proof&quot; {
# p_202 [label=&quot;Start (if :var_0:.Ros_complex_model.incoming = None then true\l       else\l         :var_0:.Ros_complex_model.mode = Ros_complex_model.Error\l         &amp;&amp; :var_0:.Ros_complex_model.outgoing = None\l         ==\&gt; :var_0:.Ros_complex_model.outgoing = None\l       :time 0.009s)&quot;,shape=box,style=filled,fontname=&quot;courier&quot;,fontsize=14];
# p_202 -&gt; p_201 [label=&quot;&quot;];
# p_201 [label=&quot;Simplify ((:var_0:.Ros_complex_model.incoming = None\l           \|\| not\l              (:var_0:.Ros_complex_model.mode = Ros_complex_model.Error\l               &amp;&amp; :var_0:.Ros_complex_model.outgoing = None))\l          \|\| :var_0:.Ros_complex_model.outgoing = None :expansions [] \l          :rw [] :fc [])&quot;,shape=box,style=filled,fontname=&quot;courier&quot;,fontsize=14];
# p_201 -&gt; p_200 [label=&quot;&quot;];
# p_200 -&gt; p_z3_333 [label=&quot;&quot;,fontname=&quot;courier&quot;,fontsize=14];
# p_z3_333 [label=&quot;(let ((a!1 (asserted (not (= (Ros_complex_model.outgoing_2591 state_2691)
#                           …&quot;,shape=box,fontname=&quot;courier&quot;,fontsize=14];p_200 [label=&quot;unsat&quot;,shape=box,style=filled,fontname=&quot;courier&quot;,fontsize=14];
# }
# </textarea><button class="btn btn-primary">Load graph</button><div class="imandra-graphviz-loading display-none">Loading..</div><div class="imandra-graphviz-target"></div><script>
# require(['nbextensions/nbimandra/graphviz'], function (graphviz) {
#   var target = '#graphviz-121b1787-02e4-4ed6-9474-9770be2cdd17';
#   graphviz.hydrate(target);
# });
# </script></div></div></div><script>
# require(['nbextensions/nbimandra/alternatives'], function (alternatives) {
#   var target = '#alt-4d2d882b-3cc2-4698-b452-31384fa9eb78';
#   alternatives.hydrate(target);
# });
# </script></div></div></div><script>
# require(['nbextensions/nbimandra/fold'], function (fold) {
#   var target = '#fold-7866e987-5288-4450-b071-99a01ae4d36f';
#   fold.hydrate(target);
# });
# </script></div></div></div><div class="tab-pane"><div class="imandra-graphviz" id="graphviz-15da71bd-eecb-45ce-87ae-ba3095ba5a12"><textarea style="display: none">digraph &quot;call graph&quot; {
# goal [label=&quot;not\l((state.Ros_complex_model.incoming = None\l  \|\| not\l     (state.Ros_complex_model.mode = Ros_complex_model.Error\l      &amp;&amp; state.Ros_complex_model.outgoing = None))\l \|\| state.Ros_complex_model.outgoing = None)&quot;,shape=box,style=filled,color=&quot;cyan&quot;,fontname=&quot;courier&quot;,fontsize=14];
# }
# </textarea><button class="btn btn-primary">Load graph</button><div class="imandra-graphviz-loading display-none">Loading..</div><div class="imandra-graphviz-target"></div><script>
# require(['nbextensions/nbimandra/graphviz'], function (graphviz) {
#   var target = '#graphviz-15da71bd-eecb-45ce-87ae-ba3095ba5a12';
#   graphviz.hydrate(target);
# });
# </script></div></div></div><script>
# require(['nbextensions/nbimandra/alternatives'], function (alternatives) {
#   var target = '#alt-6379ea32-2dfb-408e-9874-538e3c13208f';
#   alternatives.hydrate(target);
# });
# </script></div></div></div>

# %% [markdown]
# # Verifying stopping if facing a wall

# %% [markdown]
# Let us verify some more complex statement about our model -- lets prove that if the robot senses that it is too close to the wall, then it always attemps to either stop or backpedal from it. More precisely, if the front-facing sensor shows a range that is too close (say, less than 0.5 m), then our node always sends out a `Twist` message with `linear.x` velocity that is less or equal to zero.
#
# We create two helper functions that get the range of the front sensor and check that the outgoing message is a `Twist` message and its velocity is not positive:

# %%
let get_front_sensor_range state =
  match state.incoming with 
  | Some (Sensor sensor) -> List.nth 2 sensor.Sensor_msgs.laserScan_ranges 
  | _ -> None 

let no_positive_outgoing_velocity state =
let open Geometry_msgs in
  match state.outgoing with 
  | Some (Twist twist) -> twist.twist_linear.vector3_x <= 0
  | _ -> false
# Out:
# val get_front_sensor_range :
#   Ros_complex_model.state -> Basic_types.float32 option = <fun>
# val no_positive_outgoing_velocity : Ros_complex_model.state -> bool = <fun>

# %% [markdown]
# Now we can attempt to prove our goal. We require that the state incoming message is a valid `Sensor` message with the front sensor range < 0.5 m, and we want to prove that after we apply `one_call` to the state -- there is always a `Twist` message with non-positive velocity:

# %%
verify (fun  state ->
  match state.incoming with None -> true | Some msg -> 
  match get_front_sensor_range state with None -> true | Some range_front ->
  let state' = one_step state in
  (  range_front < 50000
  && valid_incoming msg  
  ) ==> 
  no_positive_outgoing_velocity state' 
)
# Out:
# - : Ros_complex_model.state -> bool = <fun>
# module CX : sig val state : Ros_complex_model.state end
# <div><div>Refuted<div class="imandra-alternatives" id="alt-0d4bd0ce-5165-4555-94fd-6a19b4848e09"><ul class="nav nav-tabs"><li class="active" data-toggle="tab"><a>call graph</a></li><li class="" data-toggle="tab"><a>proof-attempt</a></li></ul><div class="tab-content"><div class="tab-pane active"><div class="imandra-graphviz" id="graphviz-159a9eb8-2008-424b-a7ec-aed9c357d322"><textarea style="display: none">digraph &quot;call graph&quot; {
# goal [label=&quot;not\l(((state.Ros_complex_model.incoming = None\l   \|\| (if Is_a(Ros_complex_model.Sensor,\l          Option.get state.Ros_complex_model.incoming)\l          &amp;&amp; Is_a(Some, state.Ros_complex_model.incoming)\l       then\l         List.nth 2\l         (Destruct(Ros_complex_model.Sensor, 0,\l                   Option.get state.Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges\l       else None)\l      = None)\l  \|\| not\l     (not\l      (50000 \&lt;=\l       Option.get\l       (if Is_a(Ros_complex_model.Sensor,\l           Option.get state.Ros_complex_model.incoming)\l           &amp;&amp; Is_a(Some, state.Ros_complex_model.incoming)\l        then\l          List.nth 2\l          (Destruct(Ros_complex_model.Sensor, 0,\l                    Option.get state.Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges\l        else None))\l      &amp;&amp; (not\l          Is_a(Ros_complex_model.Sensor,\l          Option.get state.Ros_complex_model.incoming)\l          \|\| List.length\l             (Destruct(Ros_complex_model.Sensor, 0,\l                       Option.get state.Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges\l             = 5)))\l \|\| (Is_a(Ros_complex_model.Twist,\l     Option.get\l     (if state.Ros_complex_model.mode = Ros_complex_model.Error then …\l      else …).Ros_complex_model.outgoing)\l     &amp;&amp; Is_a(Some,\l        (if state.Ros_complex_model.mode = Ros_complex_model.Error then …\l         else …).Ros_complex_model.outgoing))\l    &amp;&amp; (Destruct(Ros_complex_model.Twist, 0,\l                 Option.get\l                 (if state.Ros_complex_model.mode = Ros_complex_model.Error\l                  then … else …).Ros_complex_model.outgoing)).Geometry_msgs.twist_linear.Geometry_msgs.vector3_x\l       \&lt;= 0)&quot;,shape=box,style=filled,color=&quot;cyan&quot;,fontname=&quot;courier&quot;,fontsize=14];
# call_3326 [label=&quot;List.length\l(List.tl\l (List.tl\l  (Destruct(Ros_complex_model.Sensor, 0, Option.get …)).Sensor_msgs.laserScan_ranges))&quot;,shape=box,style=filled,color=&quot;green&quot;,fontname=&quot;courier&quot;,fontsize=14];
# call_3326 -&gt; expr_4104 [label=&quot;=&quot;];
# expr_4104 [label=&quot;if List.tl\l   (List.tl\l    (Destruct(Ros_complex_model.Sensor, 0,\l              Option.get ….Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges)\l   = []\lthen 0\lelse\l  1\l  + List.length\l    (List.tl\l     (List.tl\l      (List.tl\l       (Destruct(Ros_complex_model.Sensor, 0,\l                 Option.get ….Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges)))&quot;,shape=box,style=filled,color=&quot;grey&quot;,fontname=&quot;courier&quot;,fontsize=14];
# expr_3803 -&gt; call_3326 [label=&quot;calls&quot;];
# call_4246 [label=&quot;List.nth (-1 + -1 + -1 + -1 + 3)\l(List.tl\l (List.tl\l  (List.tl\l   (List.tl\l    (Destruct(Ros_complex_model.Sensor, 0, Option.get …)).Sensor_msgs.laserScan_ranges))))&quot;,shape=box,style=filled,color=&quot;yellow&quot;,fontname=&quot;courier&quot;,fontsize=14];
# expr_4248 -&gt; call_4246 [label=&quot;calls&quot;];
# call_3510 [label=&quot;List.length\l(List.tl\l (Destruct(Ros_complex_model.Sensor, 0, Option.get …)).Sensor_msgs.laserScan_ranges)&quot;,shape=box,style=filled,color=&quot;green&quot;,fontname=&quot;courier&quot;,fontsize=14];
# call_3510 -&gt; expr_3803 [label=&quot;=&quot;];
# expr_3803 [label=&quot;if List.tl\l   (Destruct(Ros_complex_model.Sensor, 0,\l             Option.get ….Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges\l   = []\lthen 0\lelse\l  1\l  + List.length\l    (List.tl\l     (List.tl\l      (Destruct(Ros_complex_model.Sensor, 0,\l                Option.get ….Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges))&quot;,shape=box,style=filled,color=&quot;grey&quot;,fontname=&quot;courier&quot;,fontsize=14];
# expr_3512 -&gt; call_3510 [label=&quot;calls&quot;];
# call_1920 [label=&quot;List.nth 1\l(Destruct(Ros_complex_model.Sensor, 0, Option.get …)).Sensor_msgs.laserScan_ranges&quot;,shape=box,style=filled,color=&quot;green&quot;,fontname=&quot;courier&quot;,fontsize=14];
# call_1920 -&gt; expr_3439 [label=&quot;=&quot;];
# expr_3439 [label=&quot;if (Destruct(Ros_complex_model.Sensor, 0,\l             Option.get ….Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges\l   = []\lthen None\lelse\lif 1 = 0\lthen\l  Some\l  (List.hd\l   (Destruct(Ros_complex_model.Sensor, 0,\l             Option.get ….Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges)\lelse\l  List.nth (-1 + 1)\l  (List.tl\l   (Destruct(Ros_complex_model.Sensor, 0,\l             Option.get ….Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges)&quot;,shape=box,style=filled,color=&quot;grey&quot;,fontname=&quot;courier&quot;,fontsize=14];
# goal -&gt; call_1920 [label=&quot;calls&quot;];
# call_4023 [label=&quot;List.nth (-1 + -1 + -1 + 1)\l(List.tl\l (List.tl\l  (List.tl\l   (Destruct(Ros_complex_model.Sensor, 0, Option.get …)).Sensor_msgs.laserScan_ranges)))&quot;,shape=box,style=filled,color=&quot;green&quot;,fontname=&quot;courier&quot;,fontsize=14];
# call_4023 -&gt; expr_4293 [label=&quot;=&quot;];
# expr_4293 [label=&quot;if List.tl\l   (List.tl\l    (List.tl\l     (Destruct(Ros_complex_model.Sensor, 0,\l               Option.get ….Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges))\l   = []\lthen None\lelse\lif -1 + -1 + -1 + 1 = 0\lthen\l  Some\l  (List.hd\l   (List.tl\l    (List.tl\l     (List.tl\l      (Destruct(Ros_complex_model.Sensor, 0,\l                Option.get ….Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges))))\lelse\l  List.nth (-1 + -1 + -1 + -1 + 1)\l  (List.tl\l   (List.tl\l    (List.tl\l     (List.tl\l      (Destruct(Ros_complex_model.Sensor, 0,\l                Option.get ….Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges))))&quot;,shape=box,style=filled,color=&quot;grey&quot;,fontname=&quot;courier&quot;,fontsize=14];
# expr_4025 -&gt; call_4023 [label=&quot;calls&quot;];
# call_130 [label=&quot;List.nth 3\l(Destruct(Ros_complex_model.Sensor, 0, Option.get …)).Sensor_msgs.laserScan_ranges&quot;,shape=box,style=filled,color=&quot;green&quot;,fontname=&quot;courier&quot;,fontsize=14];
# call_130 -&gt; expr_3348 [label=&quot;=&quot;];
# expr_3348 [label=&quot;if (Destruct(Ros_complex_model.Sensor, 0,\l             Option.get ….Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges\l   = []\lthen None\lelse\lif 3 = 0\lthen\l  Some\l  (List.hd\l   (Destruct(Ros_complex_model.Sensor, 0,\l             Option.get ….Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges)\lelse\l  List.nth (-1 + 3)\l  (List.tl\l   (Destruct(Ros_complex_model.Sensor, 0,\l             Option.get ….Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges)&quot;,shape=box,style=filled,color=&quot;grey&quot;,fontname=&quot;courier&quot;,fontsize=14];
# goal -&gt; call_130 [label=&quot;calls&quot;];
# call_4289 [label=&quot;List.nth (-1 + -1 + -1 + -1 + 1)\l(List.tl\l (List.tl\l  (List.tl\l   (List.tl\l    (Destruct(Ros_complex_model.Sensor, 0, Option.get …)).Sensor_msgs.laserScan_ranges))))&quot;,shape=box,style=filled,color=&quot;yellow&quot;,fontname=&quot;courier&quot;,fontsize=14];
# expr_4293 -&gt; call_4289 [label=&quot;calls&quot;];
# call_144 [label=&quot;List.nth 2\l(Destruct(Ros_complex_model.Sensor, 0, Option.get …)).Sensor_msgs.laserScan_ranges&quot;,shape=box,style=filled,color=&quot;green&quot;,fontname=&quot;courier&quot;,fontsize=14];
# call_144 -&gt; expr_3559 [label=&quot;=&quot;];
# expr_3559 [label=&quot;if (Destruct(Ros_complex_model.Sensor, 0,\l             Op

# %% [markdown]
# We've failed to prove the theorem, and Imandra gave us a conunter example `CX` module. This module contains a state, that refutes the statement of the theorem we've attempted to prove. Lets check what is the incoming sensor range. And which outgoing message we get if we pass the state into the `one_step`:

# %%
get_front_sensor_range CX.state;;
(one_step CX.state).outgoing;;
# Out:
# - : Basic_types.float32 option = Some 49961
# - : Ros_complex_model.outgoing option = None

# %% [markdown]
# The incoming sensor range is `49961` and it is, indeed, less than `50000`. But we have no outgoing message -- because the node is in the `Error` mode:

# %%
CX.state.mode
# Out:
# - : Ros_complex_model.mode = Error

# %% [markdown]
# In the `Error` mode we are ignoring all the inputs -- so we are not getting any outgoing message (as we've proven in the theorem `error_state_ignores_messages` in the previous section). Adding the requirement that the input state is not in the `Error` mode, we successfully prove the theorem:

# %%
theorem stop_if_front_sensor_close state =
  match state.incoming with None -> true | Some msg -> 
  match get_front_sensor_range state with None -> true | Some range_front ->
  let state' = one_step state in
  (  range_front < 50000 
  && state.mode <> Error
  && valid_incoming msg  
  ) ==> 
  no_positive_outgoing_velocity state'
# Out:
# val stop_if_front_sensor_close : Ros_complex_model.state -> bool = <fun>
# <div><div>Proved<div class="imandra-alternatives" id="alt-62a77eda-204e-4c2e-bc68-fc1097822955"><ul class="nav nav-tabs"><li class="active" data-toggle="tab"><a>proof</a></li><li class="" data-toggle="tab"><a>call graph</a></li></ul><div class="tab-content"><div class="tab-pane active"><div class="imandra-proof-top"><div class="imandra-fold panel panel-default" id="fold-686f66ee-a9db-4a67-af83-5db8e85bd003"><div class="panel-heading"><div><i class="fa fa-chevron-down hidden"></i><i class="fa fa-chevron-right"></i><span>proof</span></div></div><div class="panel-body collapse"><div class="imandra-proof"><div class="imandra-alternatives" id="alt-8b2e473d-5ab4-4dcc-a572-d3cb661f8d76"><ul class="nav nav-tabs"><li class="active" data-toggle="tab"><a>summary</a></li><li class="" data-toggle="tab"><a>full</a></li><li class="" data-toggle="tab"><a>graph</a></li></ul><div class="tab-content"><div class="tab-pane active"><div class="imandra-table" id="table-8424bb66-5976-4639-88b5-d482c842e460"><table><tr><td><b>ground_instances</b></td><td>14</td></tr><tr><td><b>definitions</b></td><td>0</td></tr><tr><td><b>inductions</b></td><td>0</td></tr><tr><td><b>search_time</b></td><td><pre>0.024s</pre></td></tr><tr><td><b>details</b></td><td><div class="imandra-fold panel panel-default" id="fold-a015b7dc-3a0c-4613-bb65-cfa31a553b3c"><div class="panel-heading"><div><i class="fa fa-chevron-down hidden"></i><i class="fa fa-chevron-right"></i><span>Expand</span></div></div><div class="panel-body collapse"><div class="imandra-table" id="table-98c66f0e-d5d2-4392-8933-7aec26939fc5"><table><tr><td><b>smt_stats</b></td><td>(:added-eqs               1850
#  :arith-add-rows          13
#  :arith-assert-diseq      32
#  :arith-assert-lower      108
#  :arith-assert-upper      36
#  :arith-bound-prop        1
#  :arith-eq-adapter        37
#  :arith-fixed-eqs         9
#  :arith-pivots            7
#  :conflicts               56
#  :datatype-accessor-ax    65
#  :datatype-constructor-ax 111
#  :datatype-occurs-check   5052
#  :datatype-splits         104
#  :decisions               716
#  :del-clause              179
#  :final-checks            39
#  :max-memory              19.02
#  :memory                  18.96
#  :minimized-lits          4
#  :mk-bool-var             562
#  :mk-clause               224
#  :num-allocs              607751016
#  :num-checks              30
#  :propagations            625
#  :rlimit-count            97047
#  :seq-num-reductions      1)</td></tr></table></div></div><script>
# require(['nbextensions/nbimandra/fold'], function (fold) {
#   var target = '#fold-a015b7dc-3a0c-4613-bb65-cfa31a553b3c';
#   fold.hydrate(target);
# });
# </script></div></td></tr></table></div></div><div class="tab-pane"><div class="imandra-fold panel panel-default" id="fold-02998917-e437-432f-8c96-4acaa662df96"><div class="panel-heading"><div><i class="fa fa-chevron-down hidden"></i><i class="fa fa-chevron-right"></i><span>Expand</span></div></div><div class="panel-body collapse"><ul><li><pre>start[0.024s]
#   if :var_0:.Ros_complex_model.incoming = None then true
#   else
#   if (if Is_a(Ros_complex_model.Sensor,
#          Option.get :var_0:.Ros_complex_model.incoming)
#          &amp;&amp; Is_a(Some, :var_0:.Ros_complex_model.incoming)
#       then List.nth 2 ….Sensor_msgs.laserScan_ranges else None)
#      = None
#   then true
#   else
#     Option.get
#     (if Is_a(Ros_complex_model.Sensor,
#         Option.get :var_0:.Ros_complex_model.incoming)
#         &amp;&amp; Is_a(Some, :var_0:.Ros_complex_model.incoming)
#      then List.nth 2 ….Sensor_msgs.laserScan_ranges else None)
#     &lt; 50000
#     &amp;&amp; not (:var_0:.Ros_complex_model.mode = Ros_complex_model.Error)
#        &amp;&amp; (if Is_a(Ros_complex_model.Sensor,
#               Option.get :var_0:.Ros_complex_model.incoming)
#            then List.length ….Sensor_msgs.laserScan_ranges = 5 else true)
#     ==&gt; (if Is_a(Ros_complex_model.Twist, Option.get …) &amp;&amp; Is_a(Some, …)
#          then ….Geometry_msgs.vector3_x &lt;= 0 else false)</pre></li><li><div><h4>simplify</h4><div class="imandra-table" id="table-04269482-fa59-4697-9e28-8de39bf62b2c"><table><tr><td><b>into</b></td><td><pre>((:var_0:.Ros_complex_model.incoming = None
#   || (if Is_a(Ros_complex_model.Sensor,
#          Option.get :var_0:.Ros_complex_model.incoming)
#          &amp;&amp; Is_a(Some, :var_0:.Ros_complex_model.incoming)
#       then
#         List.nth 2
#         (Destruct(Ros_complex_model.Sensor, 0,
#                   Option.get :var_0:.Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges
#       else None)
#      = None)
#  || not
#     ((not
#       (50000 &lt;=
#        Option.get
#        (if Is_a(Ros_complex_model.Sensor,
#            Option.get :var_0:.Ros_complex_model.incoming)
#            &amp;&amp; Is_a(Some, :var_0:.Ros_complex_model.incoming)
#         then
#           List.nth 2
#           (Destruct(Ros_complex_model.Sensor, 0,
#                     Option.get :var_0:.Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges
#         else None))
#       &amp;&amp; not (:var_0:.Ros_complex_model.mode = Ros_complex_model.Error))
#      &amp;&amp; (not
#          Is_a(Ros_complex_model.Sensor,
#          Option.get :var_0:.Ros_complex_model.incoming)
#          || List.length
#             (Destruct(Ros_complex_model.Sensor, 0,
#                       Option.get :var_0:.Ros_complex_model.incoming)).Sensor_msgs.laserScan_ranges
#             = 5)))
# || (Is_a(Ros_complex_model.Twist,
#     Option.get
#     (if :var_0:.Ros_complex_model.mode = Ros_complex_model.Error then …
#      else …).Ros_complex_model.outgoing)
#     &amp;&amp; Is_a(Some,
#        (if :var_0:.Ros_complex_model.mode = Ros_complex_model.Error then …
#         else …).Ros_complex_model.outgoing))
#    &amp;&amp; (Destruct(Ros_complex_model.Twist, 0,
#                 Option.get
#                 (if :var_0:.Ros_complex_model.mode = Ros_complex_model.Error
#                  then … else …).Ros_complex_model.outgoing)).Geometry_msgs.twist_linear.Geometry_msgs.vector3_x
#       &lt;= 0</pre></td></tr><tr><td><b>expansions</b></td><td><pre>[]</pre></td></tr><tr><td><b>rewrite_steps</b></td><td><ul></ul></td></tr><tr><td><b>forward_chaining</b></td><td><ul></ul></td></tr></table></div></div></li><li><div>unroll<div class="imandra-table" id="table-f85a446a-7e2d-4b43-84d6-5e76cdb028cd"><table><tr><td><b>expr</b></td><td><pre>(let ((a!1 (Sensor_msgs.laserScan_ranges_2396
#              (get.Ros_complex_model.Sensor.0_2636
#     …</pre></td></tr><tr><td><b>expansions</b></td><td><ul></ul></td></tr></table></div></div></li><li><div>unroll<div class="imandra-table" id="table-e138447f-3e07-4a9d-9943-c2f6c3f2a9ed"><table><tr><td><b>expr</b></td><td><pre>(let ((a!1 (Sensor_msgs.laserScan_ranges_2396
#              (get.Ros_complex_model.Sensor.0_2636
#     …</pre></td></tr><tr><td><b>expansions</b></td><td><ul></ul></td></tr></table></div></div></li><li><div>unroll<div class="imandra-table" id="table-2526a763-259a-4971-b90d-744c9c192a65"><table><tr><td><b>expr</b></td><td><pre>(let ((a!1 (Sensor_msgs.laserScan_ranges_2396
#              (get.Ros_complex_model.Sensor.0_2636
#     …</pre></td></tr><tr><td><b>expansions</b></td><td><ul></ul></td></tr></table></div></div></li><li><div>unroll<div class="imandra-table" id="table-d1c31151-978f-4869-b79f-b1ca4735207e"><table><tr><td><b>expr</b></td><td><pre>(let ((a!1 (Sensor_msgs.laserScan_ranges_2396
#              (get.Ros_complex_model.Sensor.0_2636
#     …</pre></td></tr><tr><td><b>expansions</b></td><td><ul></ul></td></tr></table></div></div></li><li><div>unroll<div class="imandra-table" id="table-4d31f91b-5c27-45dc-83ca-894039454e30"><table><tr><td><b>expr</b></td><td><pre>(let ((a!1 (Sensor_msgs.laserScan_ranges_2396
#              (get.Ros_complex_model.Sensor.0_2636
#     …</pre></td></tr><tr><td><b>expansions</b></td><td><ul></ul></td></tr></table></div></div></li><li><div>unroll<div class="imandra-table" id="table-4406d2ef-cf6f-46f2-857d-b74911e9b69f"><table><tr><td><b>expr</b></td><td><pre>(let ((a!1 (Sensor_msgs.laserScan_ranges_2396
#              (get.Ros_complex_model.Sensor.0_2636
#     …</pre></

# %% [markdown]
# This illustrates how one can use Imandra to iteratively create theorems and prove their correctness or find logical inconsistencies in either the model or our specifications.
